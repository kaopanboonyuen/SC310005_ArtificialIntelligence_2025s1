# %% [markdown]
# ## 📘 Python Recap for Artificial Intelligence – `SC310005`
#
# *Unlock the Future with Intelligent Machines* 🤖✨
#
# ---
#
# - **Author:** Teerapong Panboonyuen (also known as Kao Panboonyuen)
# - **GitHub:** [kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1](https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1)
#
# ---
#
# ### 🔹 Section 1: Python Basics
#
# #### ✅ Concepts:
#
# * Variables
# * Data types: `int`, `float`, `str`, `bool`
#
# *   List item
# *   List item
#
#
# * Print and input
# * Conditionals
# * Loops
# * Functions
#
# ```python
# # Example: Basic types
# x = 10          # int
# y = 3.14        # float
# name = "AI"     # str
# status = True   # bool
#
# print("Name:", name)
# print("Sum:", x + y)
# ```
#
# ```python
# # Example: Conditional
# score = 85
# if score >= 90:
#     print("Grade A")
# elif score >= 80:
#     print("Grade B")
# else:
#     print("Grade C or below")
# ```
#
# ```python
# # Example: Loop
# for i in range(5):
#     print("Loop", i)
# ```
#
# ```python
# # Example: Function
# def greet(name):
#     return "Hello, " + name
#
# print(greet("AI Student"))
# ```
#
# ---
#
# #### 📝 Assignment 1:
#
# * รับค่า input จากผู้ใช้เป็นอายุ แล้วพิมพ์ว่า
#
#   * "เด็ก" ถ้าอายุน้อยกว่า 15
#   * "วัยรุ่น" ถ้าอายุระหว่าง 15-25
#   * "ผู้ใหญ่" ถ้าอายุมากกว่า 25
#
# ---
#
# ### 🔹 Section 2: Data Structures
#
# #### ✅ Concepts:
#
# * List, Tuple, Dictionary, Set
# * Indexing and slicing
# * List comprehension
#
# ```python
# # List
# fruits = ["apple", "banana", "mango"]
# print(fruits[0])  # indexing
# print(fruits[1:]) # slicing
#
# # Dictionary
# student = {"name": "John", "score": 95}
# print(student["name"])
#
# # Set
# numbers = {1, 2, 3, 2}
# print(numbers)  # no duplicates
#
# # List comprehension
# squares = [x**2 for x in range(5)]
# print(squares)
# ```
#
# ---
#
# #### 📝 Assignment 2:
#
# * สร้างลิสต์ที่มีเลข 1-10
# * ใช้ list comprehension เพื่อหาค่ากำลังสองของเลขที่หาร 2 ลงตัว
#
# ---
#
# ### 🔹 Section 3: Working with Libraries
#
# #### ✅ Concepts:
#
# * Importing modules
# * Using `!pip install` in Colab
#
# ```python
# import math
# import random
#
# print("Random number:", random.randint(1, 10))
# print("Square root of 16:", math.sqrt(16))
# ```
#
# ```python
# # Install a package in Colab
# !pip install numpy
# ```
#
# ---
#
# #### 📝 Assignment 3:
#
# * สุ่มตัวเลขจำนวนเต็ม 5 ตัวในช่วง 1 ถึง 100 แล้วพิมพ์เฉพาะเลขที่หารด้วย 5 ลงตัว
#
# ---
#
# ### 🔹 Section 4: NumPy Basics
#
# #### ✅ Concepts:
#
# * Creating arrays
# * Array operations
# * Indexing and slicing
#
# ```python
# import numpy as np
#
# a = np.array([1, 2, 3])
# b = np.array([4, 5, 6])
#
# print("Sum:", a + b)
# print("Square:", a ** 2)
# print("Slice:", a[:2])
# ```
#
# ```python
# # 2D array
# matrix = np.array([[1, 2], [3, 4]])
# print("Shape:", matrix.shape)
# ```
#
# ---
#
# #### 📝 Assignment 4:
#
# * สร้าง NumPy array ขนาด 1x10 ที่มีค่าตั้งแต่ 10 ถึง 100 แบบเพิ่มทีละ 10
# * คำนวณค่าเฉลี่ยของ array นี้
#
# ---
#
# ### 🔹 Section 5: Pandas Basics
#
# #### ✅ Concepts:
#
# * Creating DataFrames
# * Reading CSV
# * Accessing data with `loc`, `iloc`
#
# ```python
# import pandas as pd
#
# data = {
#     "Name": ["Alice", "Bob", "Charlie"],
#     "Score": [90, 85, 70]
# }
# df = pd.DataFrame(data)
# print(df)
#
# # Access
# print(df.loc[0])       # by index
# print(df["Score"])     # by column
# ```
#
# ```python
# # Load CSV
# # You can upload your own CSV to Colab
# df = pd.read_csv("https://raw.githubusercontent.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1/main/dataset/titanic_dataset.csv")
# df.head()
# ```
#
# ---
#
# #### 📝 Assignment 5:
#
# * สร้าง DataFrame ของนักเรียน 5 คน พร้อมคะแนนสอบ
# * คำนวณค่าเฉลี่ยของคะแนน
#
# ---
#
# ### 🔹 Section 6: Plotting with Matplotlib
#
# #### ✅ Concepts:
#
# * Simple plotting with `matplotlib.pyplot`
#
# ```python
# import matplotlib.pyplot as plt
#
# x = [1, 2, 3, 4, 5]
# y = [i**2 for i in x]
#
# plt.plot(x, y)
# plt.title("Square Function")
# plt.xlabel("x")
# plt.ylabel("y = x^2")
# plt.grid(True)
# plt.show()
# ```
#
# ---
#
# #### 📝 Assignment 6:
#
# * สร้างกราฟแท่ง (bar chart) เปรียบเทียบคะแนนของนักเรียน 5 คน
#
# ---

# %% [markdown]
# # 🚀 Artificial Intelligence - 2025 | Week 1
# *Unlock the Future with Intelligent Machines* 🤖✨
#
# **Author:** Kao Panboonyuen
# **GitHub:** [kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1](https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1)

# %% [markdown]
# ### Step 1: Load Data
#
# First, let's start by loading the dataset into a **Pandas DataFrame**.

# %%
import pandas as pd

# Load the data from the Excel file
df = pd.read_excel('https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1/raw/main/dataset/fictional_characters.xlsx')

# Display the first few rows of the dataset
# Please write your code here
# Out:
#     Character Name  Media Type                               Media Source  \
# 0   Jeffrey Powell       Novel          Adaptive intermediate flexibility
# 1  Amanda Williams    Webcomic     Stand-alone fault-tolerant flexibility
# 2       Ryan Terry       Novel  Pre-emptive attitude-oriented methodology
# 3      Diana Huang       Novel    Innovative clear-thinking knowledgebase
# 4   Olivia Collier  Video Game        Profound homogeneous data-warehouse
#
#       Genre         Role           Personality Traits  \
# 0  Thriller   Antagonist     candidate, hundred, case
# 1   Fantasy   Antagonist      through, new, community
# 2   Mystery         Hero      defense, medical, phone
# 3   Romance   Antagonist       morning, check, strong
# 4   Fantasy  Protagonist  appear, family, environment
#
#                                            Backstory         Skills/Abilities  \
# 0  Body now hope likely cup under world could total.  option, try, difference
# ...

# %% [markdown]
# ### **Count Missing Values**
#
# Check for any missing values in the dataset.

# %%
# Please write your code here
# Out:
# Character Name               0
# Media Type                   0
# Media Source                 0
# Genre                        0
# Role                         0
# Personality Traits           0
# Backstory                    0
# Skills/Abilities             0
# Appearance Description       0
# Alignment                    0
# Interests/Hobbies            0
# Relationships                0
# Significance/Impact          0
# Description                  0
# Scenario/Dialogue Example    0
# dtype: int64

# %% [markdown]
# #### **Filter by Specific Condition**
#
# Filter the dataset for a specific role, e.g., finding all **'Heroes'**.

# %%
heroes = # Please write your code here
heroes.head()
# Out:
#     Character Name  Media Type  \
# 2       Ryan Terry       Novel
# 11      Bailey Kim    Webcomic
# 16       Paul Shah       Movie
# 33  Courtney Perez    Webcomic
# 36    Anne Hancock  Video Game
#
#                                       Media Source     Genre  Role  \
# 2        Pre-emptive attitude-oriented methodology   Mystery  Hero
# 11                    Expanded logistical function    Sci-Fi  Hero
# 16                    Enhanced directional project   Mystery  Hero
# 33  Multi-tiered object-oriented pricing structure   Mystery  Hero
# 36                 Synchronized encompassing frame  Thriller  Hero
#
#          Personality Traits  \
# 2   defense, medical, phone
# 11           lay, model, or
# 16         add, threat, dog
# 33   agreement, wrong, then
# 36     forget, site, animal
#
#                                             Backstory  \
# 2   North get on listen avoid better whom recent m...
# 11  Office a attorney involve so nation southern l...
# ...

# %% [markdown]
# #### **Group Data by Media Type**
#
# Group data by **Media Type** and count the number of characters in each group.

# %%
media_counts = # Please write your code here
media_counts
# Out:
# Media Type
# Movie         306
# Novel         281
# TV Show       313
# Video Game    302
# Webcomic      298
# dtype: int64

# %% [markdown]
# #### **Count Unique Values in Columns**
#
# Count unique values in a specific column, e.g., **'Alignment'**.

# %%
alignment_counts = # Please write your code here
alignment_counts
# Out:
# Alignment
# Hero       517
# Neutral    494
# Villain    489
# Name: count, dtype: int64

# %% [markdown]
# #### **Extract Substrings**
#
# If you need to extract specific substrings from a text column, e.g., extracting a specific word from **'Description'**.

# %%
df['Short Description'] = # Please write your code here
df[['Character Name', 'Short Description']].head()
# Out:
#     Character Name                                  Short Description
# 0   Jeffrey Powell  Maintain minute evening sea. Move anything thi...
# 1  Amanda Williams  Hear side third article model research conditi...
# 2       Ryan Terry  Set wide land within medical. Bit read effect ...
# 3      Diana Huang  Represent front meeting deep. Apply culture ea...
# 4   Olivia Collier  Result college yet theory safe. Radio sense ro...

# %% [markdown]
# #### **Pivot Table**
#
# Create a pivot table to explore relationships between two columns, e.g., **'Media Type'** vs **'Role'**.

# %%
pivot_table = df.pivot_table(index='# Please write your code here', columns='# Please write your code here', aggfunc='size', fill_value=0)
pivot_table
# Out:
# Role        Antagonist  Hero  Mentor  Protagonist  Sidekick  Villain
# Media Type
# Movie               42    43      61           50        57       53
# Novel               53    54      46           40        50       38
# TV Show             51    54      44           45        68       51
# Video Game          51    53      41           44        49       64
# Webcomic            49    53      58           51        42       45

# %% [markdown]
# ### **Seaborn Data Visualizations**
#
# Now, let’s move on to **visualizing** the data using **Seaborn**, one of the best libraries for creating visually appealing plots.

# %% [markdown]
# #### **Count Plot**
#
# To show the distribution of **Role** across characters.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Please write your code here
plt.legend().remove()  # Removes the redundant legend
plt.title('Distribution of Roles in Fictional Characters')
plt.show()
# Out:
# /tmp/ipython-input-8-1611695826.py:5: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend().remove()  # Removes the redundant legend

# %% [markdown]
# #### **Bar Plot**
#
# To show the count of **characters by Alignment**.

# %%
sns.barplot(
    x=# Please write your code here
    y=# Please write your code here
    palette=sns.color_palette('Blues_d', n_colors=len(alignment_counts))
)
plt.title('Distribution of Character Alignments')
plt.xlabel('Alignment')
plt.ylabel('Count')
plt.xticks(rotation=45)  # Optional: rotate for readability if labels are long
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-9-717516583.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# ### **Data Engineering**

# %% [markdown]
# ### **1. Text Length Feature**
#
# Create a new feature that captures the length of the **Description** of each character.

# %%
df['Description Length'] = # Please write your code here
df[['Character Name', 'Description Length']].head()
# Out:
#     Character Name  Description Length
# 0   Jeffrey Powell                  80
# 1  Amanda Williams                 106
# 2       Ryan Terry                 103
# 3      Diana Huang                 119
# 4   Olivia Collier                 136

# %% [markdown]
# ### **2. Sentiment Analysis Using Hugging Face**
#
# Use Hugging Face’s **transformers** library to analyze the sentiment of each character’s **Description**.

# %%
import warnings
warnings.filterwarnings("ignore")

# Set display option to show full column content
pd.set_option('display.max_colwidth', None)

# %%
from transformers import pipeline
import pandas as pd

# Set option to show full description text
pd.set_option('display.max_colwidth', None)

# Load sample and copy
sample_df = df.head().copy()

# Load sentiment analysis model
sentiment_analyzer = pipeline('# Please write your code here', model="distilbert-base-uncased-finetuned-sst-2-english")

# Apply sentiment
sample_df.loc[:, 'Sentiment'] = sample_df['Description'].apply(lambda x: sentiment_analyzer(x)[0]['label'])

# Display full Description and Sentiment
sample_df[['Character Name', 'Description', 'Sentiment']]
# Out:
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Device set to use cpu
#     Character Name  \
# 0   Jeffrey Powell
# 1  Amanda Williams
# 2       Ryan Terry
# 3      Diana Huang
# 4   Olivia Collier
#
#                                                                                                                                 Description  \
# 0                                                          Maintain minute evening sea. Move anything think. Manager movie last speak rock.
# 1                                Hear side third article model research condition. Ok same may mean safe. Then truth raise think from seek.
# 2                                   Set wide land within medical. Bit read effect main fine the. Bed catch account receive political early.
# ...

# %%
for _, row in sample_df.iterrows():
    print(f"Name: {row['Character Name']}")
    print(f"Sentiment: {row['Sentiment']}")
    print(f"Description:\n{row['Description']}\n{'-'*80}")
# Out:
# Name: Jeffrey Powell
# Sentiment: POSITIVE
# Description:
# Maintain minute evening sea. Move anything think. Manager movie last speak rock.
# --------------------------------------------------------------------------------
# Name: Amanda Williams
# Sentiment: NEGATIVE
# Description:
# Hear side third article model research condition. Ok same may mean safe. Then truth raise think from seek.
# --------------------------------------------------------------------------------
# Name: Ryan Terry
# Sentiment: NEGATIVE
# Description:
# Set wide land within medical. Bit read effect main fine the. Bed catch account receive political early.
# --------------------------------------------------------------------------------
# Name: Diana Huang
# Sentiment: NEGATIVE
# Description:
# Represent front meeting deep. Apply culture easy theory song station team. Mind middle under site choice hair onto any.
# --------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### **Extract Named Entities (NER) Using Hugging Face**
#
# Use a Named Entity Recognition model from Hugging Face to extract entities like names, locations, etc., from **Description**.

# %%
from transformers import pipeline

# Load pre-trained NER model
ner_model = pipeline(
    '# Please write your code here',
    model='dbmdz/bert-large-cased-finetuned-conll03-english',  # Explicit model for consistency
    aggregation_strategy='simple'  # Groups tokens into complete entities
)

# Sample input text
test_text = "P'Kao received a Ph.D. in Artificial Intelligence from Chulalongkorn University."

# Run NER on the sample text
entities = ner_model(test_text)

# Print the extracted named entities
for entity in entities:
    print(f"{entity['entity_group']}: {entity['word']} (score: {entity['score']:.2f})")
# Out:
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu
# PER: P ' Kao (score: 0.97)
# ...

# %% [markdown]
# ### **Word Count Feature**
#
# Create a new feature that counts the number of words in the **Description** column.

# %%
df['Word Count'] = df['Description'].apply(lambda x: len(str(x).split()))
df[['Character Name', 'Word Count']].head()
# Out:
#     Character Name  Word Count
# 0   Jeffrey Powell          12
# 1  Amanda Williams          18
# 2       Ryan Terry          17
# 3      Diana Huang          19
# 4   Olivia Collier          21

# %% [markdown]
# ### **Create a Feature Based on Role Popularity**
#
# Create a feature based on the **count of each role** in the dataset to reflect the popularity of a role (e.g., Hero, Villain).

# %%
role_counts = df['Role'].value_counts()
df['Role Popularity'] = # Please write your code here
df[['Character Name', 'Role', 'Role Popularity']].head()
# Out:
#     Character Name         Role  Role Popularity
# 0   Jeffrey Powell   Antagonist              246
# 1  Amanda Williams   Antagonist              246
# 2       Ryan Terry         Hero              257
# 3      Diana Huang   Antagonist              246
# 4   Olivia Collier  Protagonist              230

# %% [markdown]
# ### **Create a Feature for Textual Similarity**
#
# You can calculate the similarity between **Description** and a reference string (e.g., "Hero" or "Villain") using **TF-IDF** or **pre-trained embeddings**.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Combine descriptions of all "Hero" role characters as reference
hero_text = " ".join(df[df['Role'] == 'Hero']['Description'])

# Vectorize descriptions and reference text
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['Description'])
reference_vector = vectorizer.transform([hero_text])v

# Compute cosine similarity between each description and the hero aggregate text
df['Similarity to Hero'] = # Please write your code here

# Show top 5 results with similarity scores
print(df[['Character Name', 'Similarity to Hero']].head())
# Out:
#     Character Name  Similarity to Hero
# 0   Jeffrey Powell            0.105190
# 1  Amanda Williams            0.128985
# 2       Ryan Terry            0.182291
# 3      Diana Huang            0.125053
# 4   Olivia Collier            0.138190

# %% [markdown]
# ### **Basic Text Length Stats on Description**

# %%
sample_df['Desc Length'] = sample_df['Description'].apply(lambda x: len(str(x)))
sample_df['Desc Word Count'] = sample_df['Description'].apply(lambda x: len(str(x).split()))
sample_df[['Character Name', 'Desc Length', 'Desc Word Count']]
# Out:
#     Character Name  Desc Length  Desc Word Count
# 0   Jeffrey Powell           80               12
# 1  Amanda Williams          106               18
# 2       Ryan Terry          103               17
# 3      Diana Huang          119               19
# 4   Olivia Collier          136               21

# %% [markdown]
# ### **Combine Role and Alignment into New Column**

# %%
sample_df['Role_Alignment'] = # Please write your code here
sample_df[['Character Name', 'Role', 'Alignment', 'Role_Alignment']]
# Out:
#     Character Name         Role Alignment      Role_Alignment
# 0   Jeffrey Powell   Antagonist   Villain  Antagonist_Villain
# 1  Amanda Williams   Antagonist   Villain  Antagonist_Villain
# 2       Ryan Terry         Hero      Hero           Hero_Hero
# 3      Diana Huang   Antagonist   Neutral  Antagonist_Neutral
# 4   Olivia Collier  Protagonist      Hero    Protagonist_Hero

# %% [markdown]
# ### **Check if Description Contains Word 'effect'**

# %%
sample_df['Has Effect'] = sample_df['Description'].apply(lambda x: 1 if 'effect' in str(x).lower() else 0)
sample_df[['Character Name', 'Description', 'Has Effect']]
# Out:
#     Character Name  \
# 0   Jeffrey Powell
# 1  Amanda Williams
# 2       Ryan Terry
# 3      Diana Huang
# 4   Olivia Collier
#
#                                                                                                                                 Description  \
# 0                                                          Maintain minute evening sea. Move anything think. Manager movie last speak rock.
# 1                                Hear side third article model research condition. Ok same may mean safe. Then truth raise think from seek.
# 2                                   Set wide land within medical. Bit read effect main fine the. Bed catch account receive political early.
# 3                   Represent front meeting deep. Apply culture easy theory song station team. Mind middle under site choice hair onto any.
# 4  Result college yet theory safe. Radio sense road run statement continue newspaper. Role while night other. Cost art affect begin change.
#
# ...

# %% [markdown]
# ### **Count Number of Skills Listed**

# %%
sample_df['Num Skills'] = sample_df['Skills/Abilities'].apply(lambda x: len(str(x).split(',')) if pd.notna(x) else 0)
sample_df[['Character Name', 'Skills/Abilities', 'Num Skills']]
# Out:
#     Character Name         Skills/Abilities  Num Skills
# 0   Jeffrey Powell  option, try, difference           3
# 1  Amanda Williams    year, service, debate           3
# 2       Ryan Terry       floor, threat, bad           3
# 3      Diana Huang  stay, attorney, reality           3
# 4   Olivia Collier       word, pull, enough           3

# %% [markdown]
# ### **Flag if Character is Hero**

# %%
sample_df['Is Hero'] = # Please write your code here
sample_df[['Character Name', 'Role', 'Is Hero']]
# Out:
#     Character Name         Role  Is Hero
# 0   Jeffrey Powell   Antagonist        0
# 1  Amanda Williams   Antagonist        0
# 2       Ryan Terry         Hero        1
# 3      Diana Huang   Antagonist        0
# 4   Olivia Collier  Protagonist        0

# %% [markdown]
# # 🧠 Week 1 AI Homework Summary
#
# 📌 **Task**: Create 5 custom data engineering problems and solve them using pandas with the fictional_characters dataset.
#
# ✅ **Steps**:
# - Load the dataset
# - Define & solve 5 interesting problems (text, numeric, or visual)
# - Use `pandas` only (no AI required)
# - 🏅 Bonus: Add 1 AI-powered feature using Hugging Face (e.g., sentiment, NER)
#
# 📄 **Full details**: See `AI-Homework-Assignment-Week-1.pdf`
#
# 📅 **Deadline**: To be confirmed during class

# %% [markdown]
# # 🚀 Artificial Intelligence - 2025 | Week 10 | 01-BrainTumor Dataset
# *Unlock the Future with Intelligent Machines* 🤖✨
#
# - **Author:** Teerapong Panboonyuen (also known as Kao Panboonyuen)
# - **GitHub:** [kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1](https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1)
# - **Credit and Reference** https://docs.ultralytics.com/datasets/

# %% [markdown]
# ![](https://southmiamineurology.net/wp-content/uploads/2025/02/brain-tumor-1024x1024.jpg)
# ![](https://github.com/kaopanboonyuen/panboonyuen_dataset/raw/main/public_dataset/ultralytics_dataset/brain-tumor-dataset-sample-image.png)

# %% [markdown]
# # ✅ Step 1: Install Ultralytics YOLO (latest version)

# %%
# !pip install ultralytics --upgrade --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 85.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 93.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 92.0 MB/s eta 0:00:00

# %% [markdown]
# # ✅ Step 2: Import libraries

# %%
import os, zipfile, glob, random, cv2, torch
import matplotlib.pyplot as plt
from ultralytics import YOLO
from IPython.display import Image, display

# %% [markdown]
# # 📥 Step 3: Download Brain Tumor Dataset (from Kao's repo)

# %%
# !wget -O brain-tumor.zip https://github.com/kaopanboonyuen/panboonyuen_dataset/raw/main/public_dataset/ultralytics_dataset/YOUR_DATASET.zip
# Out:
# --2025-08-19 06:47:25--  https://github.com/kaopanboonyuen/panboonyuen_dataset/raw/main/public_dataset/ultralytics_dataset/brain-tumor.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/kaopanboonyuen/panboonyuen_dataset/main/public_dataset/ultralytics_dataset/brain-tumor.zip [following]
# --2025-08-19 06:47:25--  https://raw.githubusercontent.com/kaopanboonyuen/panboonyuen_dataset/main/public_dataset/ultralytics_dataset/brain-tumor.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4420415 (4.2M) [application/zip]
# Saving to: ‘brain-tumor.zip’
#
# ...

# %% [markdown]
# # ✅ Unzip dataset

# %%
dataset_dir = "/content/datasets/YOUR_DATASET"
os.makedirs(dataset_dir, exist_ok=True)
with zipfile.ZipFile("brain-tumor.zip", 'r') as zip_ref:
    zip_ref.extractall("/content/datasets/YOUR_DATASET")

print("✅ Dataset extracted to:", dataset_dir)
print("📂 Files inside:", os.listdir(dataset_dir))
# Out:
# ✅ Dataset extracted to: /content/datasets/brain-tumor
# 📂 Files inside: ['LICENSE.txt', 'labels', 'brain-tumor.yaml', 'images']

# %% [markdown]
# # 📝 Step 4: Rewrite brain-tumor.yaml for Colab path

# %%
yaml_content = """# Brain Tumor Detection Dataset (Ultralytics format)
path: /content/datasets/brain-tumor

train: images/train
val: images/val
test:

names:
  0: YOUR_CLASS_NAME
  1: YOUR_CLASS_NAME

download: https://github.com/kaopanboonyuen/panboonyuen_dataset/raw/main/public_dataset/ultralytics_dataset/brain-tumor.zip
"""
with open(os.path.join(dataset_dir, "brain-tumor.yaml"), "w") as f:
    f.write(yaml_content)

print("✅ Rewritten brain-tumor.yaml")
# !cat /content/datasets/brain-tumor/brain-tumor.yaml
# Out:
# ✅ Rewritten brain-tumor.yaml
# # Brain Tumor Detection Dataset (Ultralytics format)
# path: /content/datasets/brain-tumor
#
# train: images/train
# val: images/val
# test:
#
# names:
#   0: negative
#   1: positive
#
# download: https://github.com/kaopanboonyuen/panboonyuen_dataset/raw/main/public_dataset/ultralytics_dataset/brain-tumor.zip

# %% [markdown]
# # 👀 Step 5: Preview dataset images

# %%
train_images = glob.glob(os.path.join(dataset_dir, "images/train/*.jpg"))
sample_images = random.sample(train_images, 4)

plt.figure(figsize=(12, 8))
for i, img_path in enumerate(sample_images):
    img = cv2.imread(img_path)[..., ::-1]  # BGR -> RGB
    plt.subplot(2, 2, i+1)
    plt.imshow(img)
    plt.axis("off")
    plt.title(f"Train Sample {i+1}")
plt.show()

# %% [markdown]
# # 🚀 Step 6: Train YOLOv8 on Brain Tumor Dataset

# %%
model = YOLO("YOUR_PRETRAINED_MODEL")  # small & fast model

results = model.train(
    data="/content/datasets/brain-tumor/YOUR_YAML_FILENAME.yaml",
    epochs=#INSERT_YOUR_FAV_EPOCH_NUMBERS,          # try 50-100 for better results
    imgsz=640,
    batch=16,
    name="yolo_brain_tumor"
)
# Out:
# ...
# Ultralytics 8.3.180 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %% [markdown]
# # 📊 Step 7: Visualize Training Results (Loss & mAP curves)

# %%
plt.figure(figsize=(12,6))
results_path = os.path.join(model.trainer.save_dir, "results.png")
if os.path.exists(results_path):
    display(Image(filename=results_path))
else:
    print("⚠️ No results.png found yet.")

# %% [markdown]
# # 📈 Step 8: Evaluate on Validation Set + Extra Plots

# %%
metrics = model.val(save=True, plots=True)  # plots=True จะ gen confusion matrix, PR curve
print("✅ Evaluation metrics:", metrics)

# Display generated metrics plots
eval_dir = model.trainer.save_dir
for plot_name in ["confusion_matrix.png", "PR_curve.png", "F1_curve.png", "P_curve.png", "R_curve.png"]:
    plot_path = os.path.join(eval_dir, plot_name)
    if os.path.exists(plot_path):
        print(f"📊 Showing {plot_name}")
        display(Image(filename=plot_path))
# Out:
# Ultralytics 8.3.180 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,006,038 parameters, 0 gradients, 8.1 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 191.5±85.9 MB/s, size: 3.4 KB)
# val: Scanning /content/datasets/brain-tumor/labels/val.cache... 223 images, 0 backgrounds, 0 corrupt: 100%|██████████| 223/223 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 14/14 [00:03<00:00,  3.54it/s]
#                    all        223        241      0.484      0.844      0.518      0.385
#               negative        142        154      0.604      0.792      0.646      0.492
#               positive         81         87      0.364      0.897       0.39      0.279
# Speed: 1.7ms preprocess, 6.1ms inference, 0.0ms loss, 2.8ms postprocess per image
# Results saved to runs/detect/yolo_brain_tumor2
# ...

# %% [markdown]
# # 🔮 Step 9: Inference on a Random Validation Image

# %%
from pathlib import Path

# %%
val_images = glob.glob(os.path.join(dataset_dir, "images/val/*.jpg"))
test_img = random.choice(val_images)

results = model(test_img, save=True)
print("🔍 Prediction done on:", test_img)

pred_img = Path(results[0].save_dir) / Path(results[0].path).name

display(Image(filename=pred_img))
# Out:
# image 1/1 /content/datasets/brain-tumor/images/val/val_1 (160).jpg: 640x640 1 negative, 1 positive, 15.0ms
# Speed: 6.1ms preprocess, 15.0ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/yolo_brain_tumor8
# 🔍 Prediction done on: /content/datasets/brain-tumor/images/val/val_1 (160).jpg

# %% [markdown]
# ![](https://www.itnonline.com/sites/default/files/BrainTumorChallenge.jpeg)

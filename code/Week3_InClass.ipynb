# %% [markdown]
# # 🚀 Artificial Intelligence - 2025 | Week 3
# *Unlock the Future with Intelligent Machines* 🤖✨
#
# **Author:** Kao Panboonyuen
# **GitHub:** [kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1](https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1)

# %% [markdown]
# ## 👨🏻‍⚕️ Supervised Learning on Cancer Dataset
#
# ### 🔹 Step 1: Load Data

# %%
# Please write your libs here

# Load the dataset
df = pd.read_csv("https://github.com/kaopanboonyuen/SC310005_ArtificialIntelligence_2025s1/raw/main/dataset/#DATASETNAME.csv")

# Preview
df.head()
# Out:
#    Age  Gender        BMI  Smoking  GeneticRisk  PhysicalActivity  \
# 0   58    Male  16.085313        0            1          8.146251
# 1   71  Female  30.828784        0            1          9.361630
# 2   48    Male  38.785084        0            2          5.135179
# 3   34  Female  30.040296        0            0          9.502792
# 4   62    Male  35.479721        0            0          5.356890
#
#    AlcoholIntake  CancerHistory  Diagnosis       Symptom
# 0       4.148219              1          1         Fever
# 1       3.519683              0          0         Cough
# 2       4.728368              0          1  Night Sweats
# 3       2.044636              0          0         Fever
# 4       3.309849              0          1   Weight Loss

# %% [markdown]
# ### 🔹 Step 2: EDA (Exploratory Data Analysis)

# %%
# Check shape and info
# Please write your code here
# Out:
# (1500, 10)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1500 non-null   int64
#  1   Gender            1500 non-null   object
#  2   BMI               1500 non-null   float64
#  3   Smoking           1500 non-null   int64
#  4   GeneticRisk       1500 non-null   int64
#  5   PhysicalActivity  1500 non-null   float64
#  6   AlcoholIntake     1500 non-null   float64
#  7   CancerHistory     1500 non-null   int64
#  8   Diagnosis         1500 non-null   int64
#  9   Symptom           1500 non-null   object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 117.3+ KB
# None

# %%
# Describe numerical columns
print(df.describe())
# Out:
#                Age          BMI      Smoking  GeneticRisk  PhysicalActivity  \
# count  1500.000000  1500.000000  1500.000000  1500.000000       1500.000000
# mean     50.320000    27.513321     0.269333     0.508667          4.897929
# std      17.640968     7.230012     0.443761     0.678895          2.866162
# min      20.000000    15.000291     0.000000     0.000000          0.002410
# 25%      35.000000    21.483134     0.000000     0.000000          2.434609
# 50%      51.000000    27.598494     0.000000     0.000000          4.834316
# 75%      66.000000    33.850837     1.000000     1.000000          7.409896
# max      80.000000    39.958688     1.000000     2.000000          9.994607
#
#        AlcoholIntake  CancerHistory    Diagnosis
# count    1500.000000    1500.000000  1500.000000
# mean        2.417987       0.144000     0.371333
# std         1.419318       0.351207     0.483322
# min         0.001215       0.000000     0.000000
# ...

# %%
# Count unique values
print(df['Gender'].value_counts())
print(df['Symptom'].value_counts())
print(df['Diagnosis'].value_counts())
# Out:
# Gender
# Female    764
# Male      736
# Name: count, dtype: int64
# Symptom
# Fatigue         203
# Cough           193
# Night Sweats    191
# Skin Changes    188
# Pain            186
# Fever           183
# Lump            180
# Weight Loss     176
# Name: count, dtype: int64
# Diagnosis
# 0    943
# 1    557
# Name: count, dtype: int64

# %%
# Visualize distribution
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(data=df, x=# Please write your code here)
plt.title("Diagnosis Distribution")
plt.show()

# %%
sns.boxplot(data=df, x='# Please write your code here', y='# Please write your code here')
plt.title("Age vs Diagnosis")
plt.show()

# %% [markdown]
# ### 🔹 Step 3: Remove "Cheating" Feature

# %%
# Remove CancerHistory (ตัวแปรขี้โกง)
df = df.drop(columns=['CancerHistory'])

# %% [markdown]
# ### 🔹 Step 4: Convert Strings to Numbers

# %%
# One-hot encode Gender and Symptom
df = pd.get_dummies(df, columns=[# Please write your code here], dummy_na=True)

# Optional: Print new columns
print(df.columns)
# Out:
# Index(['Age', 'BMI', 'Smoking', 'GeneticRisk', 'PhysicalActivity',
#        'AlcoholIntake', 'Diagnosis', 'Gender_Female', 'Gender_Male',
#        'Gender_nan', 'Symptom_Cough', 'Symptom_Fatigue', 'Symptom_Fever',
#        'Symptom_Lump', 'Symptom_Night Sweats', 'Symptom_Pain',
#        'Symptom_Skin Changes', 'Symptom_Weight Loss', 'Symptom_nan'],
#       dtype='object')

# %% [markdown]
# ### 🔹 Step 5: Train/Test Split (with seed)

# %%
from sklearn.model_selection import train_test_split

X = # Please write your code here
y = # Please write your code here

# Split with seed
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %% [markdown]
# ### 🔹 Step 6: Try 4 Supervised Models

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import joblib

# # Please write your ML model here
models = {
    "Decision Tree": YOUR_ML_MODEL_NAME(random_state=42),
    "Random Forest": YOUR_ML_MODEL_NAME(random_state=42),
    "Logistic Regression": YOUR_ML_MODEL_NAME(max_iter=1000, random_state=42),
    "Neural Network": YOUR_ML_MODEL_NAME(hidden_layer_sizes=(32, 16), max_iter=1000, random_state=42)
}

results = []

for name, model in models.items():
    # Please write your code to train the model on the training data here
    # Please write your code to make predictions on the test data here

    acc = accuracy_score(y_test, y_pred)
    pr = precision_score(y_test, y_pred)
    rc = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append([name, acc, pr, rc, f1])

    # Optional save model
    joblib.dump(model, f"{name.replace(' ', '_').lower()}_model.pkl")

# %% [markdown]
# ### 🔹 Step 7: (Optional) Grid Search → Skipped for now
#
# > “We skip grid search for today because it's time-consuming. You can use `GridSearchCV` later when you're ready to tune your model.”

# %%
# 🔍 Optional: Grid Search (Skipped for this lab)
# ------------------------------------------------
# We skip GridSearchCV in this session because it can be very slow,
# especially with large parameter grids or limited computing resources.

# But here's an example of how you could use it in future labs:

# from sklearn.model_selection import GridSearchCV

# param_grid = {
#     'max_depth': [3, 5, 10],
#     'min_samples_split': [2, 5, 10]
# }

# grid = GridSearchCV(DecisionTreeClassifier(random_state=42), param_grid, cv=5)
# grid.fit(X_train, y_train)
# print("Best Parameters:", grid.best_params_)
# print("Best Score:", grid.best_score_)

# 💡 Note to Students:
# Grid Search helps us find the best hyperparameters for our models.
# We’ll explore it in detail in future sessions when we focus on model optimization.

# %% [markdown]
# ### 🔹 Step 8: Summary DataFrame

# %%
# Create results DataFrame
results_df = pd.DataFrame(results, columns=["Model", "Accuracy", "Precision", "Recall", "F1 Score"])
results_df = results_df.round(4)
print(results_df)
# Out:
#                  Model  Accuracy  Precision  Recall  F1 Score
# 0        Decision Tree    0.7578     0.6897  0.6857    0.6877
# 1        Random Forest    0.8356     0.8855  0.6629    0.7582
# 2  Logistic Regression    0.7956     0.8029  0.6286    0.7051
# 3       Neural Network    0.7800     0.7714  0.6171    0.6857

# %% [markdown]
# ### 🔹 Step 9: Confusion Matrices + Explanation

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

for name, model in models.items():
    y_pred = model.predict(X_test)
    cm = confusion_matrix(y_test, y_pred)

    TP = cm[1, 1]
    FP = cm[0, 1]
    TN = cm[0, 0]
    FN = cm[1, 0]
    total = TP + FP + TN + FN

    disp = ConfusionMatrixDisplay(confusion_matrix=cm)
    disp.plot()
    plt.title(f"{name} Confusion Matrix")
    plt.show()

    print(f"{name} Confusion Matrix:")
    print(f"TP = {TP}, FP = {FP}, TN = {TN}, FN = {FN}\n")

    print(f"Accuracy = (TP + TN) / Total = ({TP} + {TN}) / {total} = {(TP + TN) / total:.4f}")
    print(f"Precision = TP / (TP + FP) = {TP} / ({TP} + {FP}) = {TP / (TP + FP):.4f}")
    print(f"Recall = TP / (TP + FN) = {TP} / ({TP} + {FN}) = {TP / (TP + FN):.4f}")
    precision = TP / (TP + FP) if (TP + FP) > 0 else 0
    recall = TP / (TP + FN) if (TP + FN) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    print(f"F1 Score = 2 * (Precision * Recall) / (Precision + Recall) = "
          f"2 * ({precision:.4f} * {recall:.4f}) / ({precision:.4f} + {recall:.4f}) = {f1:.4f}\n")
# Out:
# Decision Tree Confusion Matrix:
# TP = 120, FP = 54, TN = 221, FN = 55
#
# Accuracy = (TP + TN) / Total = (120 + 221) / 450 = 0.7578
# Precision = TP / (TP + FP) = 120 / (120 + 54) = 0.6897
# Recall = TP / (TP + FN) = 120 / (120 + 55) = 0.6857
# F1 Score = 2 * (Precision * Recall) / (Precision + Recall) = 2 * (0.6897 * 0.6857) / (0.6897 + 0.6857) = 0.6877
# Random Forest Confusion Matrix:
# TP = 116, FP = 15, TN = 260, FN = 59
#
# Accuracy = (TP + TN) / Total = (116 + 260) / 450 = 0.8356
# Precision = TP / (TP + FP) = 116 / (116 + 15) = 0.8855
# Recall = TP / (TP + FN) = 116 / (116 + 59) = 0.6629
# F1 Score = 2 * (Precision * Recall) / (Precision + Recall) = 2 * (0.8855 * 0.6629) / (0.8855 + 0.6629) = 0.7582
# Logistic Regression Confusion Matrix:
# TP = 110, FP = 27, TN = 248, FN = 65
#
# Accuracy = (TP + TN) / Total = (110 + 248) / 450 = 0.7956
# Precision = TP / (TP + FP) = 110 / (110 + 27) = 0.8029
# Recall = TP / (TP + FN) = 110 / (110 + 65) = 0.6286
# ...

# %% [markdown]
# ### 🔹 Step 10: Summary Graph (Who Wins?)

# %%
sns.barplot(data=results_df, x='Model', y='F1 Score')
plt.title("Model Comparison by F1 Score")
plt.ylim(0, 1)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### 🔹 Step 11: ROC-AUC Curve

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, roc_auc_score

for name, model in models.items():
    if hasattr(model, "predict_proba"):
        y_prob = model.predict_proba(X_test)[:, 1]
    else:
        y_prob = model.decision_function(X_test)

    fpr, tpr, _ = roc_curve(y_test, y_prob)
    auc = roc_auc_score(y_test, y_prob)

    plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# %% [markdown]
# # 🧠 Week 3 AI Homework Summary
#
# 📌 **Task**: Improve the cancer_med_dataset ML models by fine-tuning or exploring new machine learning techniques.
#
# ✅ **Steps**:
# - Use the provided `cancer_med_dataset.csv`
# - Try at least **5 different ML techniques** (examples: Decision Tree, Random Forest, Logistic Regression, Neural Networks, SVM, Gradient Boosting, k-NN, etc.)
# - Fine-tune hyperparameters for each model to improve performance (e.g., max_depth, n_estimators, learning rate)
# - Optionally, experiment with **modern AI approaches** like CNNs or other deep learning architectures (welcome but not required)
# - Your final models must achieve **accuracy higher than what we obtained in class**
# - Document your process, results, and insights clearly
#
# 📄 **Full details & examples**: Refer to the class notebook and materials from Week 3
#
# 📅 **Deadline**: To be confirmed during class
#
# 🏅 **Bonus**: If you try advanced techniques (e.g., ensemble methods, deep learning) or creative feature engineering, you can earn extra credit!

# %% [markdown]
# ### My Note (Dataset Maker)
#
# First, let's start by loading the dataset into a **Pandas DataFrame**.

# %%
# import pandas as pd
# import numpy as np

# # Load the data from the Excel file
# df = pd.read_csv('/content/cancer_dataset.csv')

# # Map binary values to gender labels
# df['Gender'] = df['Gender'].map({1: 'Male', 0: 'Female'})

# # Step 1: Define cancer-related symptoms (categories)
# symptoms = ['Fatigue', 'Lump', 'Weight Loss', 'Cough', 'Night Sweats', 'Pain', 'Fever', 'Skin Changes']

# # Step 2: Set random seed for reproducibility
# np.random.seed(42)

# # Step 3: Add a random Symptom column
# df['Symptom'] = np.random.choice(symptoms, size=df.shape[0])

# # Display the first few rows of the dataset
# df.head()

# %%
# df.to_csv('cancer_med_dataset.csv', index=False)
